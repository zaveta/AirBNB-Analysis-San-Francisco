# %% [markdown]
# # How have Airbnb prices changed due to COVID-19?

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# This is the most recent data (Oct, 2020) taken from the official website Airbnb http://insideairbnb.com/get-the-data.html
#
# In this Notebook, we'll look at this data, clean up, analyze, visualize, and model.
#
# And we will answer the following questions for Business Understanding:
#
# 1. What correlates best with the price?
#
# 2. How has price and busyness changed over the course of COVID-19?
#
# 4. Can we predict the price based on its features?

# %% [markdown]
# Let's begin!

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

#ml libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from xgboost import plot_importance

import tensorflow as tf
import time
from tensorflow import keras
from keras import models, layers, optimizers, regularizers
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import learning_curve
from sklearn.preprocessing import StandardScaler, MinMaxScaler
#metrics
from sklearn.metrics import r2_score, mean_squared_error

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#functions for EDA
def printColunmsInfo(df):
    df.info()
    print("\n")
    printTotalRowsAndColumns(df)
    print("---------------------------------------")
    
def printTotalRowsAndColumns(df):
    print("Total columns: ", df.shape[1])
    print("Total rows: ", df.shape[0])

# %%
def stringToNumConverter(string):
    newString = ""
    if pd.notna(string):
        for i in string:
            if i.isdigit() or i == ".":
                newString += i            
    return newString

# %%
#create dummy function
def create_dummy_df(df, cat_cols, dummy_na):
    for col in  cat_cols:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

# %%
#load data
sf_cal = pd.read_csv("datasets/calendar.csv", low_memory=False, index_col=0)
sf_list = pd.read_csv("datasets/listings.csv")
# Out:
# N:\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Listing Data Frame

# %% [markdown]
# First, let's look on Listing Data Frame. It is the biggest table. We won't need some columns because they don't make much sense for our purposes. So we will drop them.

# %%
sf_list = sf_list[['id', 'host_since', 'host_is_superhost', 'host_listings_count', 'host_response_time', 
                   'host_response_rate', 'host_acceptance_rate','neighbourhood_cleansed', 'latitude', 'longitude', 
                   'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities', 
                   'minimum_nights', 'maximum_nights', 'review_scores_rating', 'review_scores_accuracy', 
                   'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 
                   'review_scores_location', 'review_scores_value', 'availability_30', 'number_of_reviews',
                   'last_review', 'reviews_per_month', 'price']]
sf_list.head()
# Out:
#      id  host_since host_is_superhost  host_listings_count  \
# 0   958  2008-07-31                 t                    1
# 1  5858  2009-03-02                 f                    2
# 2  7918  2009-06-17                 f                   10
# 3  8142  2009-06-17                 f                   10
# 4  8339  2009-07-02                 f                    2
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0      within an hour               100%                  99%
# 1        within a day                60%                  83%
# 2  within a few hours               100%                 100%
# 3  within a few hours               100%                 100%
# 4  within a few hours               100%                   0%
#
#   neighbourhood_cleansed  latitude  longitude  ... review_scores_cleanliness  \
# 0       Western Addition  37.76931 -122.43386  ...                      10.0
# 1         Bernal Heights  37.74511 -122.42102  ...                      10.0
# 2         Haight Ashbury  37.76555 -122.45213  ...                       8.0
# 3         Haight Ashbury  37.76555 -122.45213  ...                       9.0
# 4       Western Addition  37.77525 -122.43637  ...                      10.0
#
#   review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                  10.0                         10.0                    10.0
# 1                  10.0                         10.0                    10.0
# 2                   9.0                          9.0                     9.0
# 3                  10.0                         10.0                     9.0
# 4                  10.0                         10.0                    10.0
#
#    review_scores_value  availability_30 number_of_reviews  last_review  \
# 0                 10.0               10               257   2020-07-30
# 1                  9.0               30               111   2017-08-06
# 2                  8.0               30                19   2020-03-06
# 3                  9.0               30                 8   2018-09-12
# 4                 10.0               30                28   2019-06-28
#
#    reviews_per_month    price
# 0               1.91  $132.00
# 1               0.81  $235.00
# 2               0.14   $56.00
# 3               0.11   $56.00
# 4               0.21  $750.00
#
# [5 rows x 31 columns]

# %% [markdown]
# We have left the following columns:
#
# * __'id'__ — we'll use to join tables
# * __host_since__ and __last_review__ — datatype data, we transform to categorical
# * __'host_response_time'__ — categorical data
# * __host_is_superhost__ — boolean data
# * __'host_response_rate'__ and __'host_acceptance_rate'__ — as a percentage, we will change to integer
# * __neighbourhood_cleansed'__ — neighbourhood name
# * __'latitude', 'longitude'__ — сoordinates, we use them for visualisation
# * __'room_type'__ and __property_type__ — categorical data
# * __'accommodates', 'bathrooms', 'bedrooms', 'beds'__ — numerical values describing property
# * __'amenities'__ — can be used to identify words associated with amenities
# * __'minimum_nights', 'maximum_nights'__ — numerical values
# * __'review_scores_rating'__ — numbers between 20 and 100
# * __'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', review_scores_communication', 'review_scores_location', 'review_scores_value'__ — numbers between 2 and 10
# * __availability_30__, __number_of_reviews__, __reviews_per_month__ — numerical
# * __'price'__ — target value

# %% [markdown]
# Let's convert string data to numeric.

# %%
#converting datatype of price column to integer
sf_list["price"] = sf_list["price"].apply(lambda string: ''.join(i for i in string if i.isdigit())[:-2])
sf_list["price"] = pd.to_numeric(sf_list["price"], downcast="integer")

#host_response_rate and host_acceptance_rate types to float
sf_list["host_response_rate"] = sf_list["host_acceptance_rate"].apply(lambda string: stringToNumConverter(string))
sf_list["host_response_rate"] = pd.to_numeric(sf_list["host_response_rate"], downcast="float")

sf_list["host_acceptance_rate"] = sf_list["host_acceptance_rate"].apply(lambda string: stringToNumConverter(string))
sf_list["host_acceptance_rate"] = pd.to_numeric(sf_list["host_acceptance_rate"], downcast="float")

#converting t, f value to 1 or 0
sf_list["host_is_superhost"] = sf_list["host_is_superhost"].apply((lambda string: 1 if string == "t" else 0))

#converting datatype of date columns to datetime
sf_list["last_review"] = pd.to_datetime(arg=sf_list["last_review"], errors="coerce")
sf_list["host_since"] = pd.to_datetime(arg=sf_list["host_since"], errors="coerce")

# %%
print("Listing Data Frame")
printColunmsInfo(sf_list)
# Out:
# Listing Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7274 entries, 0 to 7273
# Data columns (total 31 columns):
# id                             7274 non-null int64
# host_since                     7274 non-null datetime64[ns]
# host_is_superhost              7274 non-null int64
# host_listings_count            7274 non-null int64
# host_response_time             5321 non-null object
# host_response_rate             6393 non-null float32
# host_acceptance_rate           6393 non-null float32
# neighbourhood_cleansed         7274 non-null object
# latitude                       7274 non-null float64
# longitude                      7274 non-null float64
# property_type                  7274 non-null object
# room_type                      7274 non-null object
# accommodates                   7274 non-null int64
# bathrooms                      7185 non-null float64
# bedrooms                       6430 non-null float64
# beds                           7234 non-null float64
# amenities                      7274 non-null object
# minimum_nights                 7274 non-null int64
# maximum_nights                 7274 non-null int64
# review_scores_rating           5508 non-null float64
# review_scores_accuracy         5495 non-null float64
# review_scores_cleanliness      5495 non-null float64
# review_scores_checkin          5494 non-null float64
# review_scores_communication    5496 non-null float64
# review_scores_location         5494 non-null float64
# review_scores_value            5494 non-null float64
# availability_30                7274 non-null int64
# number_of_reviews              7274 non-null int64
# last_review                    5554 non-null datetime64[ns]
# reviews_per_month              5554 non-null float64
# price                          7274 non-null int16
# dtypes: datetime64[ns](2), float32(2), float64(13), int16(1), int64(8), object(5)
# memory usage: 1.6+ MB
#
#
# Total columns:  31
# Total rows:  7274
# ---------------------------------------

# %% [markdown]
# ### Amenities Data Frame

# %% [markdown]
# Consider the data about the amenities. This column is a set of lists enclosed in strings. So I had to use the *eval*. If you know a more elegant method, please let me know.
#
# Then we'll add columns for each amenitie, remove the common and very rare amenities.

# %%
amenitiesList = []
for item in sf_list["amenities"].value_counts().reset_index()["index"]:
    item = eval(item)
    for i in item:
        if i not in amenitiesList:
            amenitiesList.append(i)
print("Total amenities: ", len(amenitiesList))
print(amenitiesList)
# Out:
# Total amenities:  131
# ['Gym', 'Heating', 'Hot water', 'Air conditioning', 'Iron', 'Dryer', 'Carbon monoxide alarm', 'Building staff', 'Luggage dropoff allowed', 'Private entrance', 'Microwave', 'Hangers', 'Essentials', 'Smoke alarm', 'Refrigerator', 'Wifi', 'Shampoo', 'TV', 'Hair dryer', 'Washer', 'Cable TV', 'Bed linens', 'Stove', 'Coffee maker', 'Elevator', 'Laptop-friendly workspace', 'Extra pillows and blankets', 'Cooking basics', 'Dishes and silverware', 'Long term stays allowed', 'Kitchen', 'Oven', 'Dishwasher', 'BBQ grill', 'Host greets you', 'Free street parking', 'Hot tub', 'First aid kit', 'Fire extinguisher', 'Lock on bedroom door', 'Paid parking on premises', 'Lockbox', 'Bathtub', 'Garden or backyard', 'Patio or balcony', 'Indoor fireplace', 'Keypad', 'Cleaning before checkout', 'Paid parking off premises', 'Smart lock', 'Free parking on premises', 'Pool', 'Breakfast', 'Bread maker', 'Shower gel', 'Crib', 'Baking sheet', 'Ethernet connection', 'Pack ’n Play/travel crib', 'Pocket wifi', 'Bathroom essentials', 'Bedroom comforts', 'Self check-in', 'Full kitchen', 'Fireplace guards', 'Outlet covers', 'Game console', 'Private living room', 'Children’s books and toys', 'EV charger', 'High chair', 'Room-darkening shades', 'Stair gates', 'Lake access', 'Single level home', 'Kitchenette', 'Barbecue utensils', 'Beach essentials', 'Pets allowed', 'Children’s dinnerware', 'Babysitter recommendations', 'Waterfront', 'Changing table', 'Baby bath', 'Table corner guards', 'Window guards', 'Terrace', 'Day bed', 'Stand alone rain shower', 'Breakfast bar', 'Security cameras', 'Natural gas barbeque', 'Walk in closet', 'Dual vanity', 'Sonos sound system', 'Smart TV', 'Desk', 'Shower bathtub combo', 'Lounge area', 'Wet bar', 'Balcony', 'Gas fireplace', 'Baby monitor', 'Beachfront', 'Ski-in/Ski-out', 'Private hot tub', 'Shared hot tub', 'Massage table', 'Ironing board', 'Suitable for events', 'Smoking allowed', 'Piano', 'Stand alone steam shower', 'Home theater', 'Nest thermometer', 'Espresso machine', 'Outdoor kitchen', 'Wood-burning fireplace', 'Fire pit', 'Driveway parking', 'Stand alone bathtub', 'Jetted tub', 'Smart home technology', 'Office', 'Portable air conditioning', 'Wine cooler', 'Media room', 'Apple TV', 'Courtyard', 'Alarm system', 'Mini fridge']

# %%
amenities_df = sf_list[["id", "amenities"]]

#we don't need "amenities" in original data frame anymore
sf_list.drop(["amenities"], axis=1, inplace=True)

# %%
amenitiesDict = {}
for item in range(amenities_df.shape[0]):
    i_id, amenitiesSet = amenities_df.loc[item, "id"], set(eval(amenities_df.loc[item, "amenities"]))
    amenitiesDict[i_id] = amenitiesSet

for amenitie in amenitiesList:
    bilist = []
    for amId in amenities_df["id"]: 
        if amenitie in amenitiesDict[amId]:
            bilist.append(1)
        else:
            bilist.append(0)
    amenities_df.insert(loc=len(amenities_df.columns), column=amenitie, value=bilist, allow_duplicates=True)
print(amenities_df.shape)
# Out:
# (7274, 133)

# %% [markdown]
# ### Calendar Data Frame

# %%
sf_cal.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0       25662  2020-09-08         t  $125.00        $125.00             4.0
# 1       25662  2020-09-09         t  $125.00        $125.00             4.0
# 2       25662  2020-09-10         t  $126.00        $126.00             4.0
# 3       25662  2020-09-11         t  $139.00        $139.00             4.0
# 4       25662  2020-09-12         t  $151.00        $151.00             4.0
#
#    maximum_nights
# 0           180.0
# 1           180.0
# 2           180.0
# 3           180.0
# 4           180.0

# %% [markdown]
# This Data Frame has folowing columns:
# * __listing_id__ — id values, we'll use to join tables
# * __date__ — we need to change datatype to datetime
# * __available__ — it has to be boolean, so we need to change it
# * __minimum_nights, maximum_nights__ — we have same columns in Listing Data Frame, drop they later
# * __adjusted_price__, __price__ — target values

# %%
#converting datatype of price and adjusted_price columns to integer
sf_cal["price"] = sf_cal["price"].apply(lambda string: stringToNumConverter(string))
sf_cal["price"] = pd.to_numeric(sf_cal["price"], downcast="integer")

sf_cal["adjusted_price"] = sf_cal["adjusted_price"].apply(lambda string: stringToNumConverter(string))
sf_cal["adjusted_price"] = pd.to_numeric(sf_cal["adjusted_price"], downcast="integer")

#converting datatype of date columns to datetime
sf_cal["date"] = pd.to_datetime(arg=sf_cal["date"], errors="coerce")

#converting t, f value to Boolean datatype
sf_cal["available"] = sf_cal["available"].apply((lambda string: True if string == "t" else False))

# %%
print("Calendar Data Frame")
printColunmsInfo(sf_cal)
# Out:
# Calendar Data Frame
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2390652 entries, 0 to 2390651
# Data columns (total 7 columns):
# listing_id        int64
# date              datetime64[ns]
# available         bool
# price             float64
# adjusted_price    float64
# minimum_nights    float64
# maximum_nights    float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1)
# memory usage: 130.0 MB
#
#
# Total columns:  7
# Total rows:  2390652
# ---------------------------------------

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Let's analyze the data to answer the questions given at the beginning:
# #### 1. What correlates best with price?

# %% [markdown]
# ##### Does Amenities correlate with price?

# %%
amen_price_corr_neg = amenities_df.merge(sf_list[["id", "price"]], on="id").corr()[["id", "price"]].sort_values(by="price").head(10)
amen_price_corr_pos = amenities_df.merge(sf_list[["id", "price"]], on="id").corr()[["id", "price"]].sort_values(by="price").drop("price", axis=0).tail(10)

# %%
#negative correlation
amen_price_corr_neg.drop("id", axis=1).style.bar(color="#00677e", align="mid")
# Out:
# <style  type="text/css" >
#     #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, #00677e 5.0%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 15.9%, #00677e 15.9%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.5%, #00677e 33.5%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.7%, #00677e 38.7%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.1%, #00677e 41.1%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.8%, #00677e 48.8%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.8%, #00677e 50.8%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.2%, #00677e 51.2%, #00677e 100.0%, transparent 100.0%);
#         }    #T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.6%, #00677e 51.6%, #00677e 100.0%, transparent 100.0%);
#         }</style><table id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row0" class="row_heading level0 row0" >Laptop-friendly workspace</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row0_col0" class="data row0 col0" >-0.107526</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row1" class="row_heading level0 row1" >Kitchen</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row1_col0" class="data row1 col0" >-0.102176</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row2" class="row_heading level0 row2" >Lock on bedroom door</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row2_col0" class="data row2 col0" >-0.0904803</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row3" class="row_heading level0 row3" >Fire extinguisher</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row3_col0" class="data row3 col0" >-0.0715439</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row4" class="row_heading level0 row4" >Dishes and silverware</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row4_col0" class="data row4 col0" >-0.0659627</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row5" class="row_heading level0 row5" >Long term stays allowed</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row5_col0" class="data row5 col0" >-0.0633037</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row6" class="row_heading level0 row6" >Coffee maker</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row6_col0" class="data row6 col0" >-0.055081</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row7" class="row_heading level0 row7" >Extra pillows and blankets</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row7_col0" class="data row7 col0" >-0.0528781</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row8" class="row_heading level0 row8" >Free street parking</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row8_col0" class="data row8 col0" >-0.0524836</td>
#             </tr>
#             <tr>
#                         <th id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0level0_row9" class="row_heading level0 row9" >Cooking basics</th>
#                         <td id="T_c09faa22_0d9f_11eb_b942_a434d9d7a9a0row9_col0" class="data row9 col0" >-0.0520336</td>
#             </tr>
#     </tbody></table>

# %%
#positive correlation
amen_price_corr_pos.drop("id", axis=1).style.bar(color="#cd4a4c")
# Out:
# <style  type="text/css" >
#     #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 0.6%, transparent 0.6%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.7%, transparent 1.7%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.8%, transparent 1.8%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.8%, transparent 3.8%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.8%, transparent 3.8%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 10.1%, transparent 10.1%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 54.5%, transparent 54.5%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 55.0%, transparent 55.0%);
#         }    #T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 100.0%, transparent 100.0%);
#         }</style><table id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row0" class="row_heading level0 row0" >Walk in closet</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row0_col0" class="data row0 col0" >0.0873672</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row1" class="row_heading level0 row1" >Luggage dropoff allowed</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row1_col0" class="data row1 col0" >0.0883892</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row2" class="row_heading level0 row2" >Private entrance</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row2_col0" class="data row2 col0" >0.0901716</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row3" class="row_heading level0 row3" >Shower bathtub combo</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row3_col0" class="data row3 col0" >0.090372</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row4" class="row_heading level0 row4" >Stand alone rain shower</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row4_col0" class="data row4 col0" >0.0937878</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row5" class="row_heading level0 row5" >Dual vanity</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row5_col0" class="data row5 col0" >0.0938235</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row6" class="row_heading level0 row6" >Cable TV</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row6_col0" class="data row6 col0" >0.104391</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row7" class="row_heading level0 row7" >Gym</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row7_col0" class="data row7 col0" >0.179249</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row8" class="row_heading level0 row8" >Air conditioning</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row8_col0" class="data row8 col0" >0.180001</td>
#             </tr>
#             <tr>
#                         <th id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0level0_row9" class="row_heading level0 row9" >Building staff</th>
#                         <td id="T_c0a46624_0d9f_11eb_9cec_a434d9d7a9a0row9_col0" class="data row9 col0" >0.255858</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# As you can see, air conditioning, gym, and building staff are highly correlated with price. The rest of the amenities correlate either weakly or not at all.

# %% [markdown]
# ##### Does Review Scores correlate with price?

# %%
plt.subplots(figsize=(9, 6))
sns.heatmap(sf_list[['review_scores_rating', 'review_scores_accuracy',
                     'review_scores_cleanliness', 'review_scores_checkin',
                     'review_scores_communication', 'review_scores_location',
                     'review_scores_value', "number_of_reviews", 'price']].corr(),
            annot=True, fmt=".2f")

# %% [markdown]
# Review Scores correlate weakly with price, but they correlate well with each other.

# %% [markdown]
# ##### Does Housing Characteristics correlate with price?

# %%
plt.subplots(figsize=(9, 6))
sns.heatmap(sf_list[['accommodates', 'bathrooms', 'bedrooms', 'beds', 'price']].corr(),
            annot=True, fmt=".2f")

# %% [markdown]
# There is an obvious correlation. The more people you can accommodate, the more expensive it is to rent a room. Same about bedrooms and beds. But the number of bathrooms does not have a strong impact.

# %% [markdown]
# Some more dependencies on the price, which we will use in modeling:

# %%
sf_list.groupby(["room_type"]).mean().reset_index()[["room_type","price"]].style.bar(color="#cd4a4c")
# Out:
# <style  type="text/css" >
#     #T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 100.0%, transparent 100.0%);
#         }    #T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 80.7%, transparent 80.7%);
#         }    #T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 18.0%, transparent 18.0%);
#         }    #T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row3_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >room_type</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row0_col0" class="data row0 col0" >Entire home/apt</td>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row0_col1" class="data row0 col1" >324.781</td>
#             </tr>
#             <tr>
#                         <th id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row1_col0" class="data row1 col0" >Hotel room</td>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row1_col1" class="data row1 col1" >278.821</td>
#             </tr>
#             <tr>
#                         <th id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row2_col0" class="data row2 col0" >Private room</td>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row2_col1" class="data row2 col1" >129.865</td>
#             </tr>
#             <tr>
#                         <th id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row3_col0" class="data row3 col0" >Shared room</td>
#                         <td id="T_c168f7ac_0d9f_11eb_8b3e_a434d9d7a9a0row3_col1" class="data row3 col1" >87.2024</td>
#             </tr>
#     </tbody></table>

# %%
sf_list.groupby(["property_type"]).mean().reset_index()[["property_type","price"]].sort_values(by="price", ascending=False).style.bar(color="#cd4a4c")
# Out:
# <style  type="text/css" >
#     #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 100.0%, transparent 100.0%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 72.4%, transparent 72.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 44.4%, transparent 44.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 43.3%, transparent 43.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 18.0%, transparent 18.0%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 16.3%, transparent 16.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 15.8%, transparent 15.8%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 12.3%, transparent 12.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 12.0%, transparent 12.0%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 11.9%, transparent 11.9%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.8%, transparent 9.8%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.8%, transparent 9.8%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.0%, transparent 9.0%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 8.4%, transparent 8.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 8.3%, transparent 8.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 8.2%, transparent 8.2%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 7.3%, transparent 7.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 6.1%, transparent 6.1%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 6.1%, transparent 6.1%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.8%, transparent 5.8%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.7%, transparent 5.7%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.6%, transparent 5.6%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.6%, transparent 5.6%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.6%, transparent 5.6%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.5%, transparent 5.5%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.5%, transparent 5.5%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.4%, transparent 5.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.3%, transparent 5.3%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.2%, transparent 5.2%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.1%, transparent 5.1%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 4.8%, transparent 4.8%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 4.1%, transparent 4.1%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.9%, transparent 3.9%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.9%, transparent 3.9%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.7%, transparent 3.7%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.7%, transparent 3.7%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row36_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.7%, transparent 3.7%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row37_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.6%, transparent 3.6%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row38_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.4%, transparent 3.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a0row39_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.4%, transparent 3.4%);
#         }    #T_c1726e68_0d9f_11eb_b41f_a434d9d7a9a

# %%
sf_list.groupby(["host_response_time"]).mean().reset_index()[["host_response_time","price"]].style.bar(color="#cd4a4c")
# Out:
# <style  type="text/css" >
#     #T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row0_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 46.7%, transparent 46.7%);
#         }    #T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.5%, transparent 3.5%);
#         }    #T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 100.0%, transparent 100.0%);
#         }</style><table id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >host_response_time</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row0_col0" class="data row0 col0" >a few days or more</td>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row0_col1" class="data row0 col1" >183.075</td>
#             </tr>
#             <tr>
#                         <th id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row1_col0" class="data row1 col0" >within a day</td>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row1_col1" class="data row1 col1" >230.325</td>
#             </tr>
#             <tr>
#                         <th id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row2_col0" class="data row2 col0" >within a few hours</td>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row2_col1" class="data row2 col1" >186.6</td>
#             </tr>
#             <tr>
#                         <th id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row3_col0" class="data row3 col0" >within an hour</td>
#                         <td id="T_c177c4cc_0d9f_11eb_9925_a434d9d7a9a0row3_col1" class="data row3 col1" >284.239</td>
#             </tr>
#     </tbody></table>

# %%
sf_list.groupby(["host_is_superhost"]).mean().reset_index()[["host_is_superhost","price"]]
# Out:
#    host_is_superhost       price
# 0                  0  206.023579
# 1                  1  297.049307

# %%
sf_list[["number_of_reviews","price"]].corr()
# Out:
#                    number_of_reviews     price
# number_of_reviews           1.000000 -0.064426
# price                      -0.064426  1.000000

# %%
plt.subplots(figsize=(9, 6))
sns.heatmap(sf_list[["host_response_rate", "host_acceptance_rate", "minimum_nights",
                             "maximum_nights", "number_of_reviews", "price"]].corr(),
            annot=True, fmt=".2f")

# %% [markdown]
# ##### How about Neighbourhoods?

# %% [markdown]
# Let's find the most expensive neighbourhood.

# %%
#coordinates of San Francisco
sf_latitude, sf_longitude = 37.7647993, -122.4629897
#the necessary data for the map
sf_map = gpd.read_file("planning_neighborhoods/planning_neighborhoods.shp")
sf_neig_mean = sf_list.groupby(["neighbourhood_cleansed"]).mean().reset_index()
sf_map = sf_map.merge(sf_neig_mean, left_on="neighborho", right_on="neighbourhood_cleansed")

# %%
vmin, vmax = 100, 1300

fig, ax = plt.subplots(figsize = (20, 20))
ax.set_title("Average price in each neighborhood of San Francisco", fontdict={"fontsize": "25", "fontweight" : "3"})
sf_map.plot(column="price", cmap="OrRd", linewidth=0.8, ax=ax, edgecolor="0.8")

texts = []
for x, y, label in zip(sf_map.centroid.geometry.x, sf_map.centroid.geometry.y, sf_map["neighbourhood_cleansed"]):
    texts.append(plt.text(x, y, label, fontsize = 8))

sm = plt.cm.ScalarMappable(cmap="OrRd", norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)
    
ax.axis("off")
plt.show()

# %%
sf_list.groupby(["neighbourhood_cleansed"]).mean().reset_index()[["neighbourhood_cleansed","price"]].sort_values(by="price", ascending=False).style.bar(color="#cd4a4c")
# Out:
# <style  type="text/css" >
#     #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 100.0%, transparent 100.0%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 86.0%, transparent 86.0%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 34.4%, transparent 34.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 21.7%, transparent 21.7%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 20.2%, transparent 20.2%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 18.6%, transparent 18.6%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 18.4%, transparent 18.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 18.0%, transparent 18.0%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 17.5%, transparent 17.5%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 17.0%, transparent 17.0%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 13.5%, transparent 13.5%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 12.6%, transparent 12.6%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 12.6%, transparent 12.6%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 11.4%, transparent 11.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 10.6%, transparent 10.6%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 10.1%, transparent 10.1%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.5%, transparent 9.5%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.4%, transparent 9.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 9.3%, transparent 9.3%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 7.7%, transparent 7.7%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 7.2%, transparent 7.2%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 7.1%, transparent 7.1%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 6.9%, transparent 6.9%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 6.7%, transparent 6.7%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 6.3%, transparent 6.3%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 5.4%, transparent 5.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 4.8%, transparent 4.8%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.9%, transparent 3.9%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 3.4%, transparent 3.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 2.9%, transparent 2.9%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.7%, transparent 1.7%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.7%, transparent 1.7%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.5%, transparent 1.5%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row33_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.4%, transparent 1.4%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row34_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 1.0%, transparent 1.0%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row35_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#cd4a4c 0.8%, transparent 0.8%);
#         }    #T_18205e90_0da0_11eb_8152_a434d9d7a9a0row36_col1 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_18205e90_0da0_11eb_8152_a434d9d7a9a0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >neighbourhood_cleansed</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18205e90_0da0_11eb_8152_a434d9d7a9a0level0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_18205e90_0da0_11eb_8152_a434d9d7a9a0row0_col0" class="data row0 col0" >Golden Gate Park</td>
#                         <td id="T_18205e90_0da0_11eb_8152_a434d9d7a9a0row0_col1" class="data row0 col1" >1294</td>
#             </tr>
#             <tr>

# %% [markdown]
# As you can see from the map, the high price is more related to the location. The most expensive areas are Golden Gate Park and Financial District. If you look at my previous research, you understand that Golden Gate Park is quite safe, unlike the Financial District which pretty criminal.

# %% [markdown]
# All this data can be used to predict prices. But before that, let's answer the second question.

# %% [markdown]
# #### 2. How has price and busyness changed over the course of COVID-19?

# %% [markdown]
# Let's start by looking at price changes over the past year.

# %%
per = sf_cal.date.dt.to_period("M") 
g = sf_cal.groupby(per)

ax = sns.set_palette("viridis")

plt.figure(figsize=(16,6))
sns.barplot(x=g.mean().reset_index()["date"], 
            y=g.mean().reset_index()["price"])
plt.xlabel("Month", fontsize=20)
plt.ylabel("Price per night", fontsize=20)
plt.title("Average Price per night in San Francisco", fontsize=25)

plt.show()

# %% [markdown]
# During the covid period, the average price per night rose by about $33. And it does not stop growing linearly.

# %% [markdown]
# Next one is busyness.

# %%
ax = sns.set_palette("viridis")

plt.figure(figsize=(16,6))
sns.barplot(x=g.mean().reset_index()["date"], 
            y=g.mean().reset_index()["available"])
plt.xlabel("Month", fontsize=20)
plt.ylabel("Availability, proportion", fontsize=20)
plt.title("Average Availability in San Francisco", fontsize=25)

plt.show()

# %% [markdown]
# September last year was quite popular (wonderful weather). Then the decline began. But with the onset of covid, the decline intensified and reached its peak (half of the housing is vacant) by May.

# %% [markdown]
# As expected, the covid did not affect the Airbnb business in the best way. Prices have gone up and there are fewer customers. The indicators have not yet returned to their previous values.

# %% [markdown]
# To answer the last question, we have to prepare the data for modeling.

# %% [markdown]
# ### Can we predict the price based on its features?

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# #### Working with NaNs and categories variables

# %% [markdown]
# Let's turn "last_review" and "host_since" from date type to categorical values. For that, we create new columns and fill them in.

# %%
def lastReviewCategorical(row):
    if row.year <= 2016:
        return "4+ years"
    elif row.year <= 2018:
        return "2-3 years"
    elif row.year <= 2019:
        return "1-2 years"
    elif row.year == 2020:
        if row.month > 8:
            return "0-1 month"
        elif row.month > 2:
            return "2-6 months"
        elif row.month <= 2:
            return "this year"
    else :
        return "no reviews"    
    
sf_list["since_last_review"] = sf_list["last_review"].apply(lambda row : lastReviewCategorical(row))
sf_list["host_since_cat"] = sf_list["host_since"].apply(lambda row : lastReviewCategorical(row))

# %%
#drop all Nans in "price" columns
drop_sf_list = sf_list.dropna(subset=["price"], axis=0)
#create data frame with categorical values
cat_sf_list = drop_sf_list[["id", "neighbourhood_cleansed", "room_type",'property_type', "since_last_review", "host_since_cat"]]
#create data frame with nimerical
mean_sf_list = drop_sf_list[["id", "accommodates", "review_scores_rating", "bathrooms", "bedrooms", "beds",
                             "review_scores_accuracy", "review_scores_cleanliness", "availability_30",
                             "number_of_reviews", "reviews_per_month", "review_scores_communication",
                             "review_scores_location", "review_scores_value", "host_is_superhost",
                             "host_listings_count", "price"]]

# %%
num_cols = ["accommodates", "review_scores_rating", "bathrooms", "bedrooms", "beds",
            "review_scores_accuracy", "review_scores_cleanliness", "availability_30",
            "number_of_reviews", "reviews_per_month", "review_scores_communication",
            "review_scores_location", "review_scores_value", "host_is_superhost",
            "host_listings_count", "price"]
for col in num_cols:
    mean_sf_list.loc[col] = mean_sf_list[col].astype('float64').replace(0.0, 0.01) 
    mean_sf_list.loc[col] = np.log(mean_sf_list[col])
# Out:
# N:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
#
# N:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in log

# %%
#fill the mean
fill_mean = lambda col: col.fillna(col.mean())
mean_sf_list = mean_sf_list.apply(fill_mean, axis=0)

# %%
#create dummy data frame
cat_cols_lst = ["neighbourhood_cleansed", "room_type",'property_type', "since_last_review", "host_since_cat"]
dummy_sf_list = create_dummy_df(cat_sf_list, cat_cols_lst, dummy_na=False)

# %% [markdown]
# After all, we'll merge tree Data Frames: mean_sf_list, dummy_sf_list and amenities_df.

# %%
full_sf_list = dummy_sf_list.merge(amenities_df.drop(["amenities"], axis=1), on="id").merge(mean_sf_list, on="id")
# Out:
# N:\Anaconda\lib\site-packages\pandas\core\reshape\merge.py:946: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   'representation', UserWarning)

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# ## Predicting Price

# %% [markdown]
# Let's start modeling. We will try several models and compare the results.

# %%
#preparation train and test data
X = full_sf_list.drop(["price"], axis=1)
y = full_sf_list["price"]

#scaling
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=list(X.columns))

#split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %%
#writing the metrics in DataFrame
metrics_columns = ["Model Name", "r-squared train", "r-squared train test", "MSE train", "MSE test"]
metrics_df = pd.DataFrame(columns=metrics_columns)

# %%
def appendToMetricsdf(df, model_name, train_r2, test_r2, train_mse, test_mse) :
    new_row = {"Model Name" : model_name,
               "r-squared train" : train_r2,
               "r-squared train test" : test_r2,
               "MSE train" : train_mse,
               "MSE test" : test_mse }

    df = df.append(new_row, ignore_index=True)
    return df

# %% [markdown]
# ### AdaBoost regressor

# %%
adaboost_model = AdaBoostRegressor(n_estimators=20)
adaboost_model.fit(X_train, y_train)

#predict and score the model
y_test_preds = adaboost_model.predict(X_test)
y_train_preds = adaboost_model.predict(X_train)

#scoring model
test_r2 = round(r2_score(y_test, y_test_preds),4)
train_r2 = round(r2_score(y_train, y_train_preds),4)
test_mse = round(mean_squared_error(y_test, y_test_preds),4)
train_mse = round(mean_squared_error(y_train, y_train_preds),4)

print('r-squared score for training set was {}. r-squared score for test set was {}.'.format(train_r2, test_r2))
print('MSE score for training set was {}. MSE score for test set was {}.'.format(train_mse, test_mse))

#add row to metrics
metrics_df = appendToMetricsdf(metrics_df, "AdaBoost regressor", train_r2, test_r2, train_mse, test_mse)
# Out:
# r-squared score for training set was 0.49. r-squared score for test set was 0.4391.
# MSE score for training set was 0.3214. MSE score for test set was 0.3562.

# %% [markdown]
# ### Gradient Boosting for regression

# %%
gradboost_model = GradientBoostingRegressor(n_estimators=300)
gradboost_model.fit(X_train, y_train)

#predict and score the model
y_test_preds = gradboost_model.predict(X_test)
y_train_preds = gradboost_model.predict(X_train)

#scoring model
test_r2 = round(r2_score(y_test, y_test_preds),4)
train_r2 = round(r2_score(y_train, y_train_preds),4)
test_mse = round(mean_squared_error(y_test, y_test_preds),4)
train_mse = round(mean_squared_error(y_train, y_train_preds),4)

print('r-squared score for training set was {}. r-squared score for test set was {}.'.format(train_r2, test_r2))
print('MSE score for training set was {}. MSE score for test set was {}.'.format(train_mse, test_mse))

metrics_df = appendToMetricsdf(metrics_df, "Gradient Boosting", train_r2, test_r2, train_mse, test_mse)
# Out:
# r-squared score for training set was 0.8149. r-squared score for test set was 0.7022.
# MSE score for training set was 0.1167. MSE score for test set was 0.1891.

# %% [markdown]
# ### Extreme Gradient Boosting

# %%
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train, y_train)

y_train_preds = xgb_reg.predict(X_train)
y_test_preds = xgb_reg.predict(X_test)

#scoring model
test_r2 = round(r2_score(y_test, y_test_preds),4)
train_r2 = round(r2_score(y_train, y_train_preds),4)
test_mse = round(mean_squared_error(y_test, y_test_preds),4)
train_mse = round(mean_squared_error(y_train, y_train_preds),4)

print('r-squared score for training set was {}. r-squared score for test set was {}.'.format(train_r2, test_r2))
print('MSE score for training set was {}. MSE score for test set was {}.'.format(train_mse, test_mse))

metrics_df = appendToMetricsdf(metrics_df, "Extreme Gradient Boosting", train_r2, test_r2, train_mse, test_mse)
# Out:
# N:\Anaconda\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [15:58:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# r-squared score for training set was 0.7093. r-squared score for test set was 0.6544.
# MSE score for training set was 0.1832. MSE score for test set was 0.2195.

# %% [markdown]
# ### Neural Network

# %%
from keras import backend as K

def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return (1 - SS_res/(SS_tot + K.epsilon()) )

# %%
#building the model
model = models.Sequential()
model.add(layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(1, activation='linear'))

#compiling the model
model.compile(optimizer='adam', 
              loss='mse', 
              metrics=[r2_keras])

#model summary
print(model.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_29 (Dense)             (None, 128)               32000
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 131,073
# Trainable params: 131,073
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training the model
model_start = time.time()

model_history = model.fit(X_train, y_train, epochs=500, batch_size=256, validation_data=(X_test, y_test))

model_end = time.time()

print(f"Time taken to run: {round((model_end - model_start)/60,1)} minutes")
# Out:
# Train on 5091 samples, validate on 2183 samples
# Epoch 1/500
# 5091/5091 [==============================] - 0s 95us/step - loss: 7.2096 - r2_keras: -11.1515 - val_loss: 3.2810 - val_r2_keras: -4.2288
# Epoch 2/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 1.6850 - r2_keras: -1.6817 - val_loss: 1.1415 - val_r2_keras: -0.8253
# Epoch 3/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.7289 - r2_keras: -0.1738 - val_loss: 0.6238 - val_r2_keras: 0.0076
# Epoch 4/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.4415 - r2_keras: 0.2837 - val_loss: 0.4609 - val_r2_keras: 0.2664
# Epoch 5/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.3274 - r2_keras: 0.4758 - val_loss: 0.4159 - val_r2_keras: 0.3364
# Epoch 6/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.2699 - r2_keras: 0.5660 - val_loss: 0.3820 - val_r2_keras: 0.3908
# Epoch 7/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.2313 - r2_keras: 0.6235 - val_loss: 0.3598 - val_r2_keras: 0.4270
# Epoch 8/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.2040 - r2_keras: 0.6707 - val_loss: 0.3408 - val_r2_keras: 0.4563
# Epoch 9/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.1858 - r2_keras: 0.6977 - val_loss: 0.3279 - val_r2_keras: 0.4778
# Epoch 10/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.1670 - r2_keras: 0.7324 - val_loss: 0.3190 - val_r2_keras: 0.4926
# Epoch 11/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.1556 - r2_keras: 0.7478 - val_loss: 0.3114 - val_r2_keras: 0.5044
# Epoch 12/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.1441 - r2_keras: 0.7693 - val_loss: 0.3066 - val_r2_keras: 0.5123
# Epoch 13/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.1358 - r2_keras: 0.7831 - val_loss: 0.3032 - val_r2_keras: 0.5180
# Epoch 14/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.1309 - r2_keras: 0.7921 - val_loss: 0.3065 - val_r2_keras: 0.5138
# Epoch 15/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.1290 - r2_keras: 0.7964 - val_loss: 0.3042 - val_r2_keras: 0.5175
# Epoch 16/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.1236 - r2_keras: 0.7985 - val_loss: 0.2939 - val_r2_keras: 0.5309
# Epoch 17/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.1182 - r2_keras: 0.8128 - val_loss: 0.2932 - val_r2_keras: 0.5335
# Epoch 18/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.1042 - r2_keras: 0.8291 - val_loss: 0.2860 - val_r2_keras: 0.5442
# Epoch 19/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0860 - r2_keras: 0.8611 - val_loss: 0.2851 - val_r2_keras: 0.5450
# Epoch 20/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0800 - r2_keras: 0.8712 - val_loss: 0.2873 - val_r2_keras: 0.5422
# Epoch 21/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0749 - r2_keras: 0.8785 - val_loss: 0.2872 - val_r2_keras: 0.5424
# Epoch 22/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0714 - r2_keras: 0.8869 - val_loss: 0.2882 - val_r2_keras: 0.5395
# Epoch 23/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0670 - r2_keras: 0.8938 - val_loss: 0.2856 - val_r2_keras: 0.5436
# Epoch 24/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0631 - r2_keras: 0.8997 - val_loss: 0.2870 - val_r2_keras: 0.5413
# Epoch 25/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0582 - r2_keras: 0.9064 - val_loss: 0.2886 - val_r2_keras: 0.5378
# Epoch 26/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0543 - r2_keras: 0.9138 - val_loss: 0.2893 - val_r2_keras: 0.5385
# Epoch 27/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0509 - r2_keras: 0.9190 - val_loss: 0.2899 - val_r2_keras: 0.5364
# Epoch 28/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0481 - r2_keras: 0.9217 - val_loss: 0.2889 - val_r2_keras: 0.5382
# Epoch 29/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0458 - r2_keras: 0.9271 - val_loss: 0.2899 - val_r2_keras: 0.5361
# Epoch 30/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0433 - r2_keras: 0.9288 - val_loss: 0.2914 - val_r2_keras: 0.5339
# Epoch 31/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0423 - r2_keras: 0.9328 - val_loss: 0.2927 - val_r2_keras: 0.5317
# Epoch 32/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0407 - r2_keras: 0.9348 - val_loss: 0.2945 - val_r2_keras: 0.5289
# Epoch 33/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0396 - r2_keras: 0.9364 - val_loss: 0.3005 - val_r2_keras: 0.5193
# Epoch 34/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0394 - r2_keras: 0.9369 - val_loss: 0.2958 - val_r2_keras: 0.5260
# Epoch 35/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0386 - r2_keras: 0.9394 - val_loss: 0.2982 - val_r2_keras: 0.5217
# Epoch 36/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0409 - r2_keras: 0.9362 - val_loss: 0.2947 - val_r2_keras: 0.5280
# Epoch 37/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0401 - r2_keras: 0.9365 - val_loss: 0.3122 - val_r2_keras: 0.5008
# Epoch 38/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0429 - r2_keras: 0.9303 - val_loss: 0.2987 - val_r2_keras: 0.5200
# Epoch 39/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0413 - r2_keras: 0.9336 - val_loss: 0.3059 - val_r2_keras: 0.5085
# Epoch 40/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0385 - r2_keras: 0.9377 - val_loss: 0.3044 - val_r2_keras: 0.5109
# Epoch 41/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0339 - r2_keras: 0.9466 - val_loss: 0.3018 - val_r2_keras: 0.5150
# Epoch 42/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0309 - r2_keras: 0.9504 - val_loss: 0.3004 - val_r2_keras: 0.5175
# Epoch 43/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0286 - r2_keras: 0.9538 - val_loss: 0.2997 - val_r2_keras: 0.5188
# Epoch 44/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0255 - r2_keras: 0.9586 - val_loss: 0.3009 - val_r2_keras: 0.5166
# Epoch 45/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0272 - r2_keras: 0.9574 - val_loss: 0.3042 - val_r2_keras: 0.5112
# Epoch 46/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0253 - r2_keras: 0.9589 - val_loss: 0.2995 - val_r2_keras: 0.5190
# Epoch 47/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0235 - r2_keras: 0.9630 - val_loss: 0.3032 - val_r2_keras: 0.5124
# Epoch 48/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0219 - r2_keras: 0.9653 - val_loss: 0.3036 - val_r2_keras: 0.5123
# Epoch 49/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0240 - r2_keras: 0.9627 - val_loss: 0.3139 - val_r2_keras: 0.4960
# Epoch 50/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0286 - r2_keras: 0.9570 - val_loss: 0.3024 - val_r2_keras: 0.5139
# Epoch 51/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0232 - r2_keras: 0.9631 - val_loss: 0.3078 - val_r2_keras: 0.5039
# Epoch 52/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0219 - r2_keras: 0.9652 - val_loss: 0.3024 - val_r2_keras: 0.5148
# Epoch 53/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0196 - r2_keras: 0.9691 - val_loss: 0.3068 - val_r2_keras: 0.5060
# Epoch 54/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0185 - r2_keras: 0.9707 - val_loss: 0.3057 - val_r2_keras: 0.5082
# Epoch 55/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0184 - r2_keras: 0.9700 - val_loss: 0.3032 - val_r2_keras: 0.5115
# Epoch 56/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0190 - r2_keras: 0.9700 - val_loss: 0.3029 - val_r2_keras: 0.5134
# Epoch 57/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0187 - r2_keras: 0.9703 - val_loss: 0.3077 - val_r2_keras: 0.5061
# Epoch 58/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0178 - r2_keras: 0.9700 - val_loss: 0.3079 - val_r2_keras: 0.5047
# Epoch 59/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0186 - r2_keras: 0.9704 - val_loss: 0.3077 - val_r2_keras: 0.5056
# Epoch 60/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0163 - r2_keras: 0.9749 - val_loss: 0.3051 - val_r2_keras: 0.5091
# Epoch 61/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0181 - r2_keras: 0.9702 - val_loss: 0.3105 - val_r2_keras: 0.5003
# Epoch 62/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0186 - r2_keras: 0.9705 - val_loss: 0.3088 - val_r2_keras: 0.5034
# Epoch 63/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0199 - r2_keras: 0.9675 - val_loss: 0.3099 - val_r2_keras: 0.5026
# Epoch 64/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0202 - r2_keras: 0.9687 - val_loss: 0.3112 - val_r2_keras: 0.4995
# Epoch 65/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0178 - r2_keras: 0.9732 - val_loss: 0.3063 - val_r2_keras: 0.5072
# Epoch 66/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0163 - r2_keras: 0.9739 - val_loss: 0.3087 - val_r2_keras: 0.5029
# Epoch 67/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0162 - r2_keras: 0.9738 - val_loss: 0.3116 - val_r2_keras: 0.4987
# Epoch 68/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0164 - r2_keras: 0.9750 - val_loss: 0.3117 - val_r2_keras: 0.4983
# Epoch 69/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0174 - r2_keras: 0.9717 - val_loss: 0.3105 - val_r2_keras: 0.5003
# Epoch 70/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0165 - r2_keras: 0.9742 - val_loss: 0.3077 - val_r2_keras: 0.5052
# Epoch 71/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0169 - r2_keras: 0.9719 - val_loss: 0.3099 - val_r2_keras: 0.5020
# Epoch 72/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0164 - r2_keras: 0.9741 - val_loss: 0.3085 - val_r2_keras: 0.5031
# Epoch 73/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0171 - r2_keras: 0.9735 - val_loss: 0.3108 - val_r2_keras: 0.5005
# Epoch 74/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0176 - r2_keras: 0.9715 - val_loss: 0.3093 - val_r2_keras: 0.5025
# Epoch 75/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0168 - r2_keras: 0.9746 - val_loss: 0.3055 - val_r2_keras: 0.5087
# Epoch 76/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0181 - r2_keras: 0.9707 - val_loss: 0.3134 - val_r2_keras: 0.4941
# Epoch 77/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0235 - r2_keras: 0.9637 - val_loss: 0.3106 - val_r2_keras: 0.4999
# Epoch 78/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0213 - r2_keras: 0.9659 - val_loss: 0.3091 - val_r2_keras: 0.5033
# Epoch 79/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0217 - r2_keras: 0.9675 - val_loss: 0.3078 - val_r2_keras: 0.5052
# Epoch 80/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0195 - r2_keras: 0.9690 - val_loss: 0.3118 - val_r2_keras: 0.4990
# Epoch 81/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0198 - r2_keras: 0.9688 - val_loss: 0.3073 - val_r2_keras: 0.5068
# Epoch 82/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0219 - r2_keras: 0.9632 - val_loss: 0.3125 - val_r2_keras: 0.4986
# Epoch 83/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0224 - r2_keras: 0.9622 - val_loss: 0.3055 - val_r2_keras: 0.5093
# Epoch 84/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0203 - r2_keras: 0.9701 - val_loss: 0.3102 - val_r2_keras: 0.5003
# Epoch 85/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0302 - r2_keras: 0.9519 - val_loss: 0.3125 - val_r2_keras: 0.4975
# Epoch 86/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0221 - r2_keras: 0.9653 - val_loss: 0.3041 - val_r2_keras: 0.5118
# Epoch 87/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0231 - r2_keras: 0.9644 - val_loss: 0.3114 - val_r2_keras: 0.4994
# Epoch 88/500
# 5091/5091 [==============================] - 0s 34us/step - loss: 0.0371 - r2_keras: 0.9419 - val_loss: 0.3071 - val_r2_keras: 0.5052
# Epoch 89/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0443 - r2_keras: 0.9325 - val_loss: 0.3080 - val_r2_keras: 0.5059
# Epoch 90/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0321 - r2_keras: 0.9508 - val_loss: 0.3033 - val_r2_keras: 0.5112
# Epoch 91/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0275 - r2_keras: 0.9560 - val_loss: 0.3069 - val_r2_keras: 0.5052
# Epoch 92/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0264 - r2_keras: 0.9574 - val_loss: 0.2987 - val_r2_keras: 0.5190
# Epoch 93/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0216 - r2_keras: 0.9651 - val_loss: 0.3083 - val_r2_keras: 0.5033
# Epoch 94/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0274 - r2_keras: 0.9563 - val_loss: 0.3026 - val_r2_keras: 0.5137
# Epoch 95/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0284 - r2_keras: 0.9543 - val_loss: 0.3022 - val_r2_keras: 0.5130
# Epoch 96/500
# 5091/5091 [==============================] - 0s 38us/step - loss: 0.0187 - r2_keras: 0.9708 - val_loss: 0.3025 - val_r2_keras: 0.5133
# Epoch 97/500
# 5091/5091 [==============================] - 0s 36us/step - loss: 0.0174 - r2_keras: 0.9715 - val_loss: 0.3030 - val_r2_keras: 0.5135
# Epoch 98/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0165 - r2_keras: 0.9755 - val_loss: 0.3013 - val_r2_keras: 0.5148
# Epoch 99/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0172 - r2_keras: 0.9724 - val_loss: 0.3026 - val_r2_keras: 0.5135
# Epoch 100/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0156 - r2_keras: 0.9767 - val_loss: 0.3021 - val_r2_keras: 0.5141
# Epoch 101/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0166 - r2_keras: 0.9752 - val_loss: 0.3088 - val_r2_keras: 0.5043
# Epoch 102/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0160 - r2_keras: 0.9744 - val_loss: 0.3025 - val_r2_keras: 0.5130
# Epoch 103/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0171 - r2_keras: 0.9722 - val_loss: 0.3055 - val_r2_keras: 0.5075
# Epoch 104/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0169 - r2_keras: 0.9735 - val_loss: 0.2994 - val_r2_keras: 0.5185
# Epoch 105/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0164 - r2_keras: 0.9747 - val_loss: 0.3018 - val_r2_keras: 0.5139
# Epoch 106/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0155 - r2_keras: 0.9749 - val_loss: 0.2999 - val_r2_keras: 0.5175
# Epoch 107/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0141 - r2_keras: 0.9778 - val_loss: 0.2986 - val_r2_keras: 0.5196
# Epoch 108/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0155 - r2_keras: 0.9755 - val_loss: 0.3037 - val_r2_keras: 0.5114
# Epoch 109/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0148 - r2_keras: 0.9770 - val_loss: 0.3006 - val_r2_keras: 0.5168
# Epoch 110/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0153 - r2_keras: 0.9751 - val_loss: 0.2985 - val_r2_keras: 0.5208
# Epoch 111/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0135 - r2_keras: 0.9783 - val_loss: 0.3040 - val_r2_keras: 0.5110
# Epoch 112/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0143 - r2_keras: 0.9767 - val_loss: 0.2990 - val_r2_keras: 0.5193
# Epoch 113/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0157 - r2_keras: 0.9753 - val_loss: 0.3035 - val_r2_keras: 0.5113
# Epoch 114/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0186 - r2_keras: 0.9717 - val_loss: 0.3135 - val_r2_keras: 0.4972
# Epoch 115/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0182 - r2_keras: 0.9712 - val_loss: 0.2976 - val_r2_keras: 0.5217
# Epoch 116/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0177 - r2_keras: 0.9713 - val_loss: 0.3042 - val_r2_keras: 0.5109
# Epoch 117/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0155 - r2_keras: 0.9758 - val_loss: 0.3002 - val_r2_keras: 0.5182
# Epoch 118/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0151 - r2_keras: 0.9750 - val_loss: 0.2997 - val_r2_keras: 0.5190
# Epoch 119/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0153 - r2_keras: 0.9774 - val_loss: 0.2961 - val_r2_keras: 0.5235
# Epoch 120/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0144 - r2_keras: 0.9768 - val_loss: 0.3013 - val_r2_keras: 0.5160
# Epoch 121/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0149 - r2_keras: 0.9770 - val_loss: 0.2991 - val_r2_keras: 0.5187
# Epoch 122/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0158 - r2_keras: 0.9762 - val_loss: 0.3021 - val_r2_keras: 0.5153
# Epoch 123/500
# 5091/5091 [==============================] - 0s 30us/step - loss: 0.0160 - r2_keras: 0.9767 - val_loss: 0.2999 - val_r2_keras: 0.5183
# Epoch 124/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0161 - r2_keras: 0.9750 - val_loss: 0.2981 - val_r2_keras: 0.5213
# Epoch 125/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0161 - r2_keras: 0.9765 - val_loss: 0.2989 - val_r2_keras: 0.5202
# Epoch 126/500
# 5091/5091 [==============================] - 0s 36us/step - loss: 0.0164 - r2_keras: 0.9738 - val_loss: 0.2975 - val_r2_keras: 0.5220
# Epoch 127/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0147 - r2_keras: 0.9766 - val_loss: 0.3013 - val_r2_keras: 0.5161
# Epoch 128/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0177 - r2_keras: 0.9721 - val_loss: 0.2986 - val_r2_keras: 0.5209
# Epoch 129/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0197 - r2_keras: 0.9694 - val_loss: 0.3028 - val_r2_keras: 0.5143
# Epoch 130/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0231 - r2_keras: 0.9639 - val_loss: 0.3001 - val_r2_keras: 0.5179
# Epoch 131/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0217 - r2_keras: 0.9658 - val_loss: 0.2964 - val_r2_keras: 0.5234
# Epoch 132/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0235 - r2_keras: 0.9633 - val_loss: 0.2983 - val_r2_keras: 0.5221
# Epoch 133/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0196 - r2_keras: 0.9698 - val_loss: 0.2954 - val_r2_keras: 0.5243
# Epoch 134/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0195 - r2_keras: 0.9696 - val_loss: 0.2973 - val_r2_keras: 0.5216
# Epoch 135/500
# 5091/5091 [==============================] - 0s 30us/step - loss: 0.0196 - r2_keras: 0.9690 - val_loss: 0.3008 - val_r2_keras: 0.5174
# Epoch 136/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0230 - r2_keras: 0.9640 - val_loss: 0.3000 - val_r2_keras: 0.5188
# Epoch 137/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0208 - r2_keras: 0.9675 - val_loss: 0.2947 - val_r2_keras: 0.5261
# Epoch 138/500
# 5091/5091 [==============================] - 0s 34us/step - loss: 0.0190 - r2_keras: 0.9688 - val_loss: 0.2967 - val_r2_keras: 0.5247
# Epoch 139/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0182 - r2_keras: 0.9708 - val_loss: 0.2993 - val_r2_keras: 0.5193
# Epoch 140/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0195 - r2_keras: 0.9682 - val_loss: 0.3021 - val_r2_keras: 0.5154
# Epoch 141/500
# 5091/5091 [==============================] - 0s 33us/step - loss: 0.0204 - r2_keras: 0.9677 - val_loss: 0.2939 - val_r2_keras: 0.5276
# Epoch 142/500
# 5091/5091 [==============================] - 0s 33us/step - loss: 0.0188 - r2_keras: 0.9700 - val_loss: 0.3050 - val_r2_keras: 0.5121
# Epoch 143/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0185 - r2_keras: 0.9704 - val_loss: 0.2999 - val_r2_keras: 0.5169
# Epoch 144/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0191 - r2_keras: 0.9707 - val_loss: 0.3027 - val_r2_keras: 0.5150
# Epoch 145/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0185 - r2_keras: 0.9701 - val_loss: 0.2962 - val_r2_keras: 0.5238
# Epoch 146/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0175 - r2_keras: 0.9726 - val_loss: 0.2975 - val_r2_keras: 0.5236
# Epoch 147/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0157 - r2_keras: 0.9756 - val_loss: 0.2951 - val_r2_keras: 0.5259
# Epoch 148/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0151 - r2_keras: 0.9760 - val_loss: 0.2946 - val_r2_keras: 0.5277
# Epoch 149/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0163 - r2_keras: 0.9747 - val_loss: 0.2979 - val_r2_keras: 0.5215
# Epoch 150/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0174 - r2_keras: 0.9725 - val_loss: 0.2950 - val_r2_keras: 0.5273
# Epoch 151/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0168 - r2_keras: 0.9731 - val_loss: 0.2970 - val_r2_keras: 0.5230
# Epoch 152/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0203 - r2_keras: 0.9671 - val_loss: 0.2949 - val_r2_keras: 0.5284
# Epoch 153/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0221 - r2_keras: 0.9657 - val_loss: 0.3015 - val_r2_keras: 0.5154
# Epoch 154/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0254 - r2_keras: 0.9604 - val_loss: 0.2983 - val_r2_keras: 0.5227
# Epoch 155/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0246 - r2_keras: 0.9604 - val_loss: 0.2971 - val_r2_keras: 0.5228
# Epoch 156/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0217 - r2_keras: 0.9654 - val_loss: 0.2933 - val_r2_keras: 0.5305
# Epoch 157/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0214 - r2_keras: 0.9667 - val_loss: 0.2972 - val_r2_keras: 0.5227
# Epoch 158/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0216 - r2_keras: 0.9665 - val_loss: 0.2928 - val_r2_keras: 0.5321
# Epoch 159/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0195 - r2_keras: 0.9697 - val_loss: 0.2957 - val_r2_keras: 0.5248
# Epoch 160/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0216 - r2_keras: 0.9671 - val_loss: 0.3013 - val_r2_keras: 0.5165
# Epoch 161/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0229 - r2_keras: 0.9644 - val_loss: 0.2972 - val_r2_keras: 0.5226
# Epoch 162/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0236 - r2_keras: 0.9633 - val_loss: 0.2959 - val_r2_keras: 0.5261
# Epoch 163/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0249 - r2_keras: 0.9611 - val_loss: 0.2954 - val_r2_keras: 0.5268
# Epoch 164/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0213 - r2_keras: 0.9654 - val_loss: 0.2989 - val_r2_keras: 0.5218
# Epoch 165/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0194 - r2_keras: 0.9691 - val_loss: 0.2895 - val_r2_keras: 0.5353
# Epoch 166/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0171 - r2_keras: 0.9738 - val_loss: 0.2892 - val_r2_keras: 0.5366
# Epoch 167/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0165 - r2_keras: 0.9735 - val_loss: 0.2912 - val_r2_keras: 0.5325
# Epoch 168/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0160 - r2_keras: 0.9736 - val_loss: 0.2895 - val_r2_keras: 0.5356
# Epoch 169/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0164 - r2_keras: 0.9742 - val_loss: 0.2934 - val_r2_keras: 0.5305
# Epoch 170/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0145 - r2_keras: 0.9781 - val_loss: 0.2884 - val_r2_keras: 0.5375
# Epoch 171/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0160 - r2_keras: 0.9743 - val_loss: 0.2949 - val_r2_keras: 0.5280
# Epoch 172/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0166 - r2_keras: 0.9735 - val_loss: 0.2879 - val_r2_keras: 0.5379
# Epoch 173/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0145 - r2_keras: 0.9769 - val_loss: 0.2880 - val_r2_keras: 0.5385
# Epoch 174/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0159 - r2_keras: 0.9750 - val_loss: 0.2930 - val_r2_keras: 0.5289
# Epoch 175/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0155 - r2_keras: 0.9757 - val_loss: 0.2922 - val_r2_keras: 0.5320
# Epoch 176/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0147 - r2_keras: 0.9781 - val_loss: 0.2907 - val_r2_keras: 0.5333
# Epoch 177/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0156 - r2_keras: 0.9758 - val_loss: 0.2896 - val_r2_keras: 0.5365
# Epoch 178/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0141 - r2_keras: 0.9775 - val_loss: 0.2874 - val_r2_keras: 0.5390
# Epoch 179/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0173 - r2_keras: 0.9733 - val_loss: 0.3030 - val_r2_keras: 0.5160
# Epoch 180/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0185 - r2_keras: 0.9712 - val_loss: 0.2957 - val_r2_keras: 0.5260
# Epoch 181/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0209 - r2_keras: 0.9676 - val_loss: 0.2934 - val_r2_keras: 0.5312
# Epoch 182/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0199 - r2_keras: 0.9689 - val_loss: 0.2870 - val_r2_keras: 0.5400
# Epoch 183/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0233 - r2_keras: 0.9638 - val_loss: 0.2981 - val_r2_keras: 0.5238
# Epoch 184/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0236 - r2_keras: 0.9627 - val_loss: 0.2868 - val_r2_keras: 0.5412
# Epoch 185/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0202 - r2_keras: 0.9690 - val_loss: 0.2906 - val_r2_keras: 0.5342
# Epoch 186/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0206 - r2_keras: 0.9689 - val_loss: 0.2898 - val_r2_keras: 0.5349
# Epoch 187/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0222 - r2_keras: 0.9659 - val_loss: 0.2869 - val_r2_keras: 0.5411
# Epoch 188/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0183 - r2_keras: 0.9708 - val_loss: 0.2852 - val_r2_keras: 0.5424
# Epoch 189/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0177 - r2_keras: 0.9722 - val_loss: 0.2860 - val_r2_keras: 0.5431
# Epoch 190/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0186 - r2_keras: 0.9711 - val_loss: 0.2860 - val_r2_keras: 0.5412
# Epoch 191/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0211 - r2_keras: 0.9657 - val_loss: 0.2861 - val_r2_keras: 0.5425
# Epoch 192/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0256 - r2_keras: 0.9605 - val_loss: 0.2998 - val_r2_keras: 0.5192
# Epoch 193/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0271 - r2_keras: 0.9568 - val_loss: 0.2876 - val_r2_keras: 0.5391
# Epoch 194/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0317 - r2_keras: 0.9504 - val_loss: 0.2902 - val_r2_keras: 0.5366
# Epoch 195/500
# 5091/5091 [==============================] - ETA: 0s - loss: 0.0283 - r2_keras: 0.95 - 0s 23us/step - loss: 0.0269 - r2_keras: 0.9579 - val_loss: 0.2904 - val_r2_keras: 0.5339
# Epoch 196/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0204 - r2_keras: 0.9672 - val_loss: 0.2867 - val_r2_keras: 0.5413
# Epoch 197/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0226 - r2_keras: 0.9661 - val_loss: 0.2841 - val_r2_keras: 0.5453
# Epoch 198/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0243 - r2_keras: 0.9614 - val_loss: 0.2807 - val_r2_keras: 0.5506
# Epoch 199/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0230 - r2_keras: 0.9634 - val_loss: 0.2905 - val_r2_keras: 0.5336
# Epoch 200/500
# 5091/5091 [==============================] - ETA: 0s - loss: 0.0201 - r2_keras: 0.96 - 0s 23us/step - loss: 0.0263 - r2_keras: 0.9589 - val_loss: 0.2845 - val_r2_keras: 0.5432
# Epoch 201/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0275 - r2_keras: 0.9548 - val_loss: 0.2885 - val_r2_keras: 0.5384
# Epoch 202/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0234 - r2_keras: 0.9624 - val_loss: 0.2856 - val_r2_keras: 0.5421
# Epoch 203/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0252 - r2_keras: 0.9613 - val_loss: 0.2928 - val_r2_keras: 0.5317
# Epoch 204/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0234 - r2_keras: 0.9625 - val_loss: 0.2859 - val_r2_keras: 0.5413
# Epoch 205/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0262 - r2_keras: 0.9588 - val_loss: 0.2913 - val_r2_keras: 0.5332
# Epoch 206/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0264 - r2_keras: 0.9578 - val_loss: 0.3019 - val_r2_keras: 0.5133
# Epoch 207/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0324 - r2_keras: 0.9485 - val_loss: 0.2864 - val_r2_keras: 0.5420
# Epoch 208/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0218 - r2_keras: 0.9658 - val_loss: 0.2869 - val_r2_keras: 0.5399
# Epoch 209/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0192 - r2_keras: 0.9696 - val_loss: 0.2831 - val_r2_keras: 0.5464
# Epoch 210/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0168 - r2_keras: 0.9739 - val_loss: 0.2808 - val_r2_keras: 0.5502
# Epoch 211/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0149 - r2_keras: 0.9765 - val_loss: 0.2866 - val_r2_keras: 0.5402
# Epoch 212/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0158 - r2_keras: 0.9755 - val_loss: 0.2806 - val_r2_keras: 0.5512
# Epoch 213/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0139 - r2_keras: 0.9784 - val_loss: 0.2821 - val_r2_keras: 0.5482
# Epoch 214/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0157 - r2_keras: 0.9759 - val_loss: 0.2850 - val_r2_keras: 0.5442
# Epoch 215/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0156 - r2_keras: 0.9756 - val_loss: 0.2813 - val_r2_keras: 0.5499
# Epoch 216/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0167 - r2_keras: 0.9739 - val_loss: 0.3019 - val_r2_keras: 0.5181
# Epoch 217/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0216 - r2_keras: 0.9668 - val_loss: 0.2844 - val_r2_keras: 0.5453
# Epoch 218/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0170 - r2_keras: 0.9731 - val_loss: 0.2848 - val_r2_keras: 0.5432
# Epoch 219/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0166 - r2_keras: 0.9741 - val_loss: 0.2806 - val_r2_keras: 0.5510
# Epoch 220/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0148 - r2_keras: 0.9750 - val_loss: 0.2831 - val_r2_keras: 0.5467
# Epoch 221/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0159 - r2_keras: 0.9755 - val_loss: 0.2794 - val_r2_keras: 0.5531
# Epoch 222/500
# 5091/5091 [==============================] - 0s 30us/step - loss: 0.0155 - r2_keras: 0.9749 - val_loss: 0.2825 - val_r2_keras: 0.5492
# Epoch 223/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0146 - r2_keras: 0.9764 - val_loss: 0.2810 - val_r2_keras: 0.5496
# Epoch 224/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0149 - r2_keras: 0.9763 - val_loss: 0.2842 - val_r2_keras: 0.5465
# Epoch 225/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0145 - r2_keras: 0.9770 - val_loss: 0.2811 - val_r2_keras: 0.5509
# Epoch 226/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0186 - r2_keras: 0.9697 - val_loss: 0.2844 - val_r2_keras: 0.5443
# Epoch 227/500
# 5091/5091 [==============================] - 0s 30us/step - loss: 0.0175 - r2_keras: 0.9713 - val_loss: 0.2842 - val_r2_keras: 0.5452
# Epoch 228/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0167 - r2_keras: 0.9734 - val_loss: 0.2843 - val_r2_keras: 0.5459
# Epoch 229/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0154 - r2_keras: 0.9761 - val_loss: 0.2814 - val_r2_keras: 0.5500
# Epoch 230/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0140 - r2_keras: 0.9782 - val_loss: 0.2842 - val_r2_keras: 0.5462
# Epoch 231/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0135 - r2_keras: 0.9773 - val_loss: 0.2863 - val_r2_keras: 0.5412
# Epoch 232/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0146 - r2_keras: 0.9785 - val_loss: 0.2820 - val_r2_keras: 0.5494
# Epoch 233/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0145 - r2_keras: 0.9783 - val_loss: 0.2820 - val_r2_keras: 0.5483
# Epoch 234/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0148 - r2_keras: 0.9769 - val_loss: 0.2791 - val_r2_keras: 0.5538
# Epoch 235/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0166 - r2_keras: 0.9742 - val_loss: 0.2824 - val_r2_keras: 0.5492
# Epoch 236/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0152 - r2_keras: 0.9765 - val_loss: 0.2813 - val_r2_keras: 0.5504
# Epoch 237/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0137 - r2_keras: 0.9777 - val_loss: 0.2800 - val_r2_keras: 0.5529
# Epoch 238/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0139 - r2_keras: 0.9787 - val_loss: 0.2807 - val_r2_keras: 0.5512
# Epoch 239/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0139 - r2_keras: 0.9780 - val_loss: 0.2815 - val_r2_keras: 0.5509
# Epoch 240/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0153 - r2_keras: 0.9774 - val_loss: 0.2882 - val_r2_keras: 0.5387
# Epoch 241/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0172 - r2_keras: 0.9732 - val_loss: 0.2812 - val_r2_keras: 0.5499
# Epoch 242/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0166 - r2_keras: 0.9742 - val_loss: 0.2808 - val_r2_keras: 0.5512
# Epoch 243/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0161 - r2_keras: 0.9743 - val_loss: 0.2863 - val_r2_keras: 0.5413
# Epoch 244/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0179 - r2_keras: 0.9710 - val_loss: 0.2818 - val_r2_keras: 0.5510
# Epoch 245/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0186 - r2_keras: 0.9708 - val_loss: 0.2833 - val_r2_keras: 0.5470
# Epoch 246/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0158 - r2_keras: 0.9746 - val_loss: 0.2785 - val_r2_keras: 0.5551
# Epoch 247/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0139 - r2_keras: 0.9783 - val_loss: 0.2823 - val_r2_keras: 0.5489
# Epoch 248/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0135 - r2_keras: 0.9787 - val_loss: 0.2807 - val_r2_keras: 0.5520
# Epoch 249/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0155 - r2_keras: 0.9767 - val_loss: 0.2830 - val_r2_keras: 0.5480
# Epoch 250/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0159 - r2_keras: 0.9747 - val_loss: 0.2809 - val_r2_keras: 0.5514
# Epoch 251/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0186 - r2_keras: 0.9701 - val_loss: 0.2866 - val_r2_keras: 0.5408
# Epoch 252/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0177 - r2_keras: 0.9719 - val_loss: 0.2837 - val_r2_keras: 0.5466
# Epoch 253/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0204 - r2_keras: 0.9671 - val_loss: 0.2899 - val_r2_keras: 0.5348
# Epoch 254/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0192 - r2_keras: 0.9694 - val_loss: 0.2830 - val_r2_keras: 0.5470
# Epoch 255/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0198 - r2_keras: 0.9685 - val_loss: 0.2853 - val_r2_keras: 0.5440
# Epoch 256/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0173 - r2_keras: 0.9718 - val_loss: 0.2804 - val_r2_keras: 0.5530
# Epoch 257/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0188 - r2_keras: 0.9706 - val_loss: 0.2823 - val_r2_keras: 0.5481
# Epoch 258/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0243 - r2_keras: 0.9598 - val_loss: 0.2861 - val_r2_keras: 0.5440
# Epoch 259/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0195 - r2_keras: 0.9686 - val_loss: 0.2803 - val_r2_keras: 0.5522
# Epoch 260/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0172 - r2_keras: 0.9726 - val_loss: 0.2837 - val_r2_keras: 0.5472
# Epoch 261/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0168 - r2_keras: 0.9741 - val_loss: 0.2786 - val_r2_keras: 0.5533
# Epoch 262/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0189 - r2_keras: 0.9696 - val_loss: 0.2851 - val_r2_keras: 0.5441
# Epoch 263/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0190 - r2_keras: 0.9703 - val_loss: 0.2792 - val_r2_keras: 0.5540
# Epoch 264/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0163 - r2_keras: 0.9738 - val_loss: 0.2842 - val_r2_keras: 0.5474
# Epoch 265/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0191 - r2_keras: 0.9704 - val_loss: 0.2749 - val_r2_keras: 0.5604
# Epoch 266/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0186 - r2_keras: 0.9701 - val_loss: 0.2848 - val_r2_keras: 0.5457
# Epoch 267/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0207 - r2_keras: 0.9670 - val_loss: 0.2739 - val_r2_keras: 0.5617
# Epoch 268/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0222 - r2_keras: 0.9661 - val_loss: 0.2814 - val_r2_keras: 0.5520
# Epoch 269/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0265 - r2_keras: 0.9540 - val_loss: 0.2859 - val_r2_keras: 0.5405
# Epoch 270/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0317 - r2_keras: 0.9506 - val_loss: 0.2903 - val_r2_keras: 0.5402
# Epoch 271/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0350 - r2_keras: 0.9440 - val_loss: 0.2839 - val_r2_keras: 0.5468
# Epoch 272/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0406 - r2_keras: 0.9352 - val_loss: 0.2789 - val_r2_keras: 0.5546
# Epoch 273/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0380 - r2_keras: 0.9391 - val_loss: 0.2789 - val_r2_keras: 0.5533
# Epoch 274/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0326 - r2_keras: 0.9481 - val_loss: 0.2792 - val_r2_keras: 0.5545
# Epoch 275/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0217 - r2_keras: 0.9651 - val_loss: 0.2775 - val_r2_keras: 0.5569
# Epoch 276/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0219 - r2_keras: 0.9646 - val_loss: 0.2764 - val_r2_keras: 0.5583
# Epoch 277/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0191 - r2_keras: 0.9707 - val_loss: 0.2776 - val_r2_keras: 0.5560
# Epoch 278/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0211 - r2_keras: 0.9665 - val_loss: 0.2793 - val_r2_keras: 0.5551
# Epoch 279/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0200 - r2_keras: 0.9670 - val_loss: 0.2731 - val_r2_keras: 0.5626
# Epoch 280/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0212 - r2_keras: 0.9652 - val_loss: 0.2787 - val_r2_keras: 0.5540
# Epoch 281/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0162 - r2_keras: 0.9747 - val_loss: 0.2778 - val_r2_keras: 0.5561
# Epoch 282/500
# 5091/5091 [==============================] - 0s 35us/step - loss: 0.0157 - r2_keras: 0.9752 - val_loss: 0.2818 - val_r2_keras: 0.5503
# Epoch 283/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0182 - r2_keras: 0.9714 - val_loss: 0.2745 - val_r2_keras: 0.5604
# Epoch 284/500
# 5091/5091 [==============================] - 0s 30us/step - loss: 0.0171 - r2_keras: 0.9733 - val_loss: 0.2719 - val_r2_keras: 0.5656
# Epoch 285/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0172 - r2_keras: 0.9721 - val_loss: 0.2749 - val_r2_keras: 0.5608
# Epoch 286/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0157 - r2_keras: 0.9754 - val_loss: 0.2767 - val_r2_keras: 0.5580
# Epoch 287/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0147 - r2_keras: 0.9755 - val_loss: 0.2730 - val_r2_keras: 0.5631
# Epoch 288/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0142 - r2_keras: 0.9774 - val_loss: 0.2722 - val_r2_keras: 0.5655
# Epoch 289/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0153 - r2_keras: 0.9752 - val_loss: 0.2712 - val_r2_keras: 0.5672
# Epoch 290/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0153 - r2_keras: 0.9770 - val_loss: 0.2750 - val_r2_keras: 0.5602
# Epoch 291/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0146 - r2_keras: 0.9766 - val_loss: 0.2768 - val_r2_keras: 0.5571
# Epoch 292/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0138 - r2_keras: 0.9788 - val_loss: 0.2741 - val_r2_keras: 0.5615
# Epoch 293/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0140 - r2_keras: 0.9783 - val_loss: 0.2718 - val_r2_keras: 0.5654
# Epoch 294/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0141 - r2_keras: 0.9782 - val_loss: 0.2756 - val_r2_keras: 0.5591
# Epoch 295/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0158 - r2_keras: 0.9753 - val_loss: 0.2748 - val_r2_keras: 0.5598
# Epoch 296/500
# 5091/5091 [==============================] - 0s 29us/step - loss: 0.0158 - r2_keras: 0.9762 - val_loss: 0.2753 - val_r2_keras: 0.5596
# Epoch 297/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0146 - r2_keras: 0.9772 - val_loss: 0.2700 - val_r2_keras: 0.5681
# Epoch 298/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0132 - r2_keras: 0.9789 - val_loss: 0.2738 - val_r2_keras: 0.5638
# Epoch 299/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0154 - r2_keras: 0.9758 - val_loss: 0.2742 - val_r2_keras: 0.5624
# Epoch 300/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0148 - r2_keras: 0.9766 - val_loss: 0.2733 - val_r2_keras: 0.5641
# Epoch 301/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0146 - r2_keras: 0.9770 - val_loss: 0.2736 - val_r2_keras: 0.5616
# Epoch 302/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0149 - r2_keras: 0.9761 - val_loss: 0.2722 - val_r2_keras: 0.5654
# Epoch 303/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0141 - r2_keras: 0.9776 - val_loss: 0.2710 - val_r2_keras: 0.5666
# Epoch 304/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0167 - r2_keras: 0.9747 - val_loss: 0.2799 - val_r2_keras: 0.5528
# Epoch 305/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0186 - r2_keras: 0.9708 - val_loss: 0.2791 - val_r2_keras: 0.5528
# Epoch 306/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0172 - r2_keras: 0.9724 - val_loss: 0.2750 - val_r2_keras: 0.5612
# Epoch 307/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0165 - r2_keras: 0.9738 - val_loss: 0.2724 - val_r2_keras: 0.5644
# Epoch 308/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0155 - r2_keras: 0.9761 - val_loss: 0.2758 - val_r2_keras: 0.5607
# Epoch 309/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0157 - r2_keras: 0.9754 - val_loss: 0.2726 - val_r2_keras: 0.5647
# Epoch 310/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0175 - r2_keras: 0.9723 - val_loss: 0.2733 - val_r2_keras: 0.5638
# Epoch 311/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0162 - r2_keras: 0.9742 - val_loss: 0.2699 - val_r2_keras: 0.5688
# Epoch 312/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0158 - r2_keras: 0.9757 - val_loss: 0.2756 - val_r2_keras: 0.5609
# Epoch 313/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0170 - r2_keras: 0.9739 - val_loss: 0.2730 - val_r2_keras: 0.5639
# Epoch 314/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0171 - r2_keras: 0.9734 - val_loss: 0.2713 - val_r2_keras: 0.5672
# Epoch 315/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0168 - r2_keras: 0.9738 - val_loss: 0.2695 - val_r2_keras: 0.5694
# Epoch 316/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0149 - r2_keras: 0.9761 - val_loss: 0.2763 - val_r2_keras: 0.5603
# Epoch 317/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0141 - r2_keras: 0.9784 - val_loss: 0.2709 - val_r2_keras: 0.5679
# Epoch 318/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0140 - r2_keras: 0.9787 - val_loss: 0.2759 - val_r2_keras: 0.5602
# Epoch 319/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0166 - r2_keras: 0.9734 - val_loss: 0.2823 - val_r2_keras: 0.5499
# Epoch 320/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0208 - r2_keras: 0.9668 - val_loss: 0.2776 - val_r2_keras: 0.5585
# Epoch 321/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0193 - r2_keras: 0.9687 - val_loss: 0.2703 - val_r2_keras: 0.5676
# Epoch 322/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0163 - r2_keras: 0.9754 - val_loss: 0.2733 - val_r2_keras: 0.5635
# Epoch 323/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0161 - r2_keras: 0.9759 - val_loss: 0.2694 - val_r2_keras: 0.5707
# Epoch 324/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0144 - r2_keras: 0.9778 - val_loss: 0.2738 - val_r2_keras: 0.5623
# Epoch 325/500
# ...
# Epoch 394/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0127 - r2_keras: 0.9811 - val_loss: 0.2657 - val_r2_keras: 0.5772
# Epoch 395/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0123 - r2_keras: 0.9799 - val_loss: 0.2676 - val_r2_keras: 0.5736
# Epoch 396/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0133 - r2_keras: 0.9793 - val_loss: 0.2664 - val_r2_keras: 0.5753
# Epoch 397/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0128 - r2_keras: 0.9805 - val_loss: 0.2657 - val_r2_keras: 0.5766
# Epoch 398/500
# 5091/5091 [==============================] - 0s 31us/step - loss: 0.0130 - r2_keras: 0.9797 - val_loss: 0.2694 - val_r2_keras: 0.5713
# Epoch 399/500
# 5091/5091 [==============================] - 0s 37us/step - loss: 0.0140 - r2_keras: 0.9766 - val_loss: 0.2681 - val_r2_keras: 0.5719
# Epoch 400/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0146 - r2_keras: 0.9766 - val_loss: 0.2724 - val_r2_keras: 0.5670
# Epoch 401/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0164 - r2_keras: 0.9733 - val_loss: 0.2687 - val_r2_keras: 0.5719
# Epoch 402/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0196 - r2_keras: 0.9694 - val_loss: 0.2710 - val_r2_keras: 0.5691
# Epoch 403/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0170 - r2_keras: 0.9731 - val_loss: 0.2664 - val_r2_keras: 0.5751
# Epoch 404/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0140 - r2_keras: 0.9780 - val_loss: 0.2738 - val_r2_keras: 0.5649
# Epoch 405/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0158 - r2_keras: 0.9752 - val_loss: 0.2754 - val_r2_keras: 0.5626
# Epoch 406/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0172 - r2_keras: 0.9723 - val_loss: 0.2725 - val_r2_keras: 0.5663
# Epoch 407/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0160 - r2_keras: 0.9742 - val_loss: 0.2692 - val_r2_keras: 0.5718
# Epoch 408/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0180 - r2_keras: 0.9721 - val_loss: 0.2755 - val_r2_keras: 0.5617
# Epoch 409/500
# 5091/5091 [==============================] - ETA: 0s - loss: 0.0168 - r2_keras: 0.97 - 0s 23us/step - loss: 0.0181 - r2_keras: 0.9700 - val_loss: 0.2751 - val_r2_keras: 0.5614
# Epoch 410/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0189 - r2_keras: 0.9695 - val_loss: 0.2712 - val_r2_keras: 0.5687
# Epoch 411/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0165 - r2_keras: 0.9736 - val_loss: 0.2764 - val_r2_keras: 0.5600
# Epoch 412/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0176 - r2_keras: 0.9716 - val_loss: 0.2668 - val_r2_keras: 0.5755
# Epoch 413/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0155 - r2_keras: 0.9756 - val_loss: 0.2684 - val_r2_keras: 0.5724
# Epoch 414/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0123 - r2_keras: 0.9812 - val_loss: 0.2699 - val_r2_keras: 0.5722
# Epoch 415/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0138 - r2_keras: 0.9777 - val_loss: 0.2708 - val_r2_keras: 0.5692
# Epoch 416/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0141 - r2_keras: 0.9779 - val_loss: 0.2712 - val_r2_keras: 0.5695
# Epoch 417/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0141 - r2_keras: 0.9771 - val_loss: 0.2719 - val_r2_keras: 0.5683
# Epoch 418/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0147 - r2_keras: 0.9778 - val_loss: 0.2633 - val_r2_keras: 0.5800
# Epoch 419/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0191 - r2_keras: 0.9684 - val_loss: 0.2760 - val_r2_keras: 0.5622
# Epoch 420/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0158 - r2_keras: 0.9755 - val_loss: 0.2657 - val_r2_keras: 0.5775
# Epoch 421/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0179 - r2_keras: 0.9723 - val_loss: 0.2606 - val_r2_keras: 0.5839
# Epoch 422/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0152 - r2_keras: 0.9764 - val_loss: 0.2733 - val_r2_keras: 0.5655
# Epoch 423/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0162 - r2_keras: 0.9749 - val_loss: 0.2646 - val_r2_keras: 0.5787
# Epoch 424/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0145 - r2_keras: 0.9778 - val_loss: 0.2643 - val_r2_keras: 0.5794
# Epoch 425/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0133 - r2_keras: 0.9799 - val_loss: 0.2619 - val_r2_keras: 0.5828
# Epoch 426/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0130 - r2_keras: 0.9788 - val_loss: 0.2656 - val_r2_keras: 0.5768
# Epoch 427/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0142 - r2_keras: 0.9783 - val_loss: 0.2666 - val_r2_keras: 0.5762
# Epoch 428/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0137 - r2_keras: 0.9786 - val_loss: 0.2652 - val_r2_keras: 0.5777
# Epoch 429/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0130 - r2_keras: 0.9790 - val_loss: 0.2647 - val_r2_keras: 0.5792
# Epoch 430/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0127 - r2_keras: 0.9807 - val_loss: 0.2654 - val_r2_keras: 0.5782
# Epoch 431/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0138 - r2_keras: 0.9782 - val_loss: 0.2620 - val_r2_keras: 0.5831
# Epoch 432/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0117 - r2_keras: 0.9823 - val_loss: 0.2635 - val_r2_keras: 0.5804
# Epoch 433/500
# 5091/5091 [==============================] - ETA: 0s - loss: 0.0070 - r2_keras: 0.98 - 0s 23us/step - loss: 0.0118 - r2_keras: 0.9810 - val_loss: 0.2610 - val_r2_keras: 0.5846
# Epoch 434/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0110 - r2_keras: 0.9824 - val_loss: 0.2624 - val_r2_keras: 0.5825
# Epoch 435/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0113 - r2_keras: 0.9827 - val_loss: 0.2627 - val_r2_keras: 0.5823
# Epoch 436/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0125 - r2_keras: 0.9805 - val_loss: 0.2628 - val_r2_keras: 0.5817
# Epoch 437/500
# 5091/5091 [==============================] - ETA: 0s - loss: 0.0107 - r2_keras: 0.98 - 0s 23us/step - loss: 0.0138 - r2_keras: 0.9769 - val_loss: 0.2660 - val_r2_keras: 0.5772
# Epoch 438/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0142 - r2_keras: 0.9782 - val_loss: 0.2626 - val_r2_keras: 0.5825
# Epoch 439/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0159 - r2_keras: 0.9741 - val_loss: 0.2599 - val_r2_keras: 0.5856
# Epoch 440/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0154 - r2_keras: 0.9750 - val_loss: 0.2720 - val_r2_keras: 0.5674
# Epoch 441/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0171 - r2_keras: 0.9718 - val_loss: 0.2692 - val_r2_keras: 0.5730
# Epoch 442/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0140 - r2_keras: 0.9777 - val_loss: 0.2638 - val_r2_keras: 0.5796
# Epoch 443/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0166 - r2_keras: 0.9749 - val_loss: 0.2680 - val_r2_keras: 0.5745
# Epoch 444/500
# 5091/5091 [==============================] - 0s 25us/step - loss: 0.0183 - r2_keras: 0.9723 - val_loss: 0.2692 - val_r2_keras: 0.5732
# Epoch 445/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0161 - r2_keras: 0.9734 - val_loss: 0.2648 - val_r2_keras: 0.5789
# Epoch 446/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0158 - r2_keras: 0.9752 - val_loss: 0.2672 - val_r2_keras: 0.5760
# Epoch 447/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0174 - r2_keras: 0.9714 - val_loss: 0.2725 - val_r2_keras: 0.5682
# Epoch 448/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0201 - r2_keras: 0.9694 - val_loss: 0.2665 - val_r2_keras: 0.5759
# Epoch 449/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0208 - r2_keras: 0.9669 - val_loss: 0.2734 - val_r2_keras: 0.5645
# Epoch 450/500
# 5091/5091 [==============================] - 0s 27us/step - loss: 0.0194 - r2_keras: 0.9694 - val_loss: 0.2681 - val_r2_keras: 0.5733
# Epoch 451/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0188 - r2_keras: 0.9706 - val_loss: 0.2725 - val_r2_keras: 0.5651
# Epoch 452/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0182 - r2_keras: 0.9711 - val_loss: 0.2671 - val_r2_keras: 0.5774
# Epoch 453/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0173 - r2_keras: 0.9718 - val_loss: 0.2655 - val_r2_keras: 0.5786
# Epoch 454/500
# 5091/5091 [==============================] - 0s 28us/step - loss: 0.0162 - r2_keras: 0.9742 - val_loss: 0.2753 - val_r2_keras: 0.5647
# Epoch 455/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0157 - r2_keras: 0.9755 - val_loss: 0.2632 - val_r2_keras: 0.5802
# Epoch 456/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0138 - r2_keras: 0.9788 - val_loss: 0.2744 - val_r2_keras: 0.5662
# Epoch 457/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0128 - r2_keras: 0.9804 - val_loss: 0.2650 - val_r2_keras: 0.5791
# Epoch 458/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0114 - r2_keras: 0.9823 - val_loss: 0.2672 - val_r2_keras: 0.5767
# Epoch 459/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0122 - r2_keras: 0.9817 - val_loss: 0.2680 - val_r2_keras: 0.5745
# Epoch 460/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0142 - r2_keras: 0.9775 - val_loss: 0.2672 - val_r2_keras: 0.5771
# Epoch 461/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0117 - r2_keras: 0.9816 - val_loss: 0.2697 - val_r2_keras: 0.5706
# Epoch 462/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0127 - r2_keras: 0.9804 - val_loss: 0.2731 - val_r2_keras: 0.5671
# Epoch 463/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0128 - r2_keras: 0.9804 - val_loss: 0.2652 - val_r2_keras: 0.5787
# Epoch 464/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0127 - r2_keras: 0.9801 - val_loss: 0.2662 - val_r2_keras: 0.5778
# Epoch 465/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0134 - r2_keras: 0.9786 - val_loss: 0.2688 - val_r2_keras: 0.5740
# Epoch 466/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0134 - r2_keras: 0.9788 - val_loss: 0.2689 - val_r2_keras: 0.5740
# Epoch 467/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0131 - r2_keras: 0.9789 - val_loss: 0.2663 - val_r2_keras: 0.5780
# Epoch 468/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0130 - r2_keras: 0.9799 - val_loss: 0.2676 - val_r2_keras: 0.5750
# Epoch 469/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0146 - r2_keras: 0.9778 - val_loss: 0.2645 - val_r2_keras: 0.5800
# Epoch 470/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0121 - r2_keras: 0.9802 - val_loss: 0.2672 - val_r2_keras: 0.5756
# Epoch 471/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0127 - r2_keras: 0.9795 - val_loss: 0.2725 - val_r2_keras: 0.5674
# Epoch 472/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0125 - r2_keras: 0.9794 - val_loss: 0.2654 - val_r2_keras: 0.5791
# Epoch 473/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0136 - r2_keras: 0.9790 - val_loss: 0.2709 - val_r2_keras: 0.5708
# Epoch 474/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0142 - r2_keras: 0.9777 - val_loss: 0.2688 - val_r2_keras: 0.5733
# Epoch 475/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0129 - r2_keras: 0.9790 - val_loss: 0.2716 - val_r2_keras: 0.5701
# Epoch 476/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0126 - r2_keras: 0.9806 - val_loss: 0.2657 - val_r2_keras: 0.5779
# Epoch 477/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0151 - r2_keras: 0.9763 - val_loss: 0.2736 - val_r2_keras: 0.5666
# Epoch 478/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0137 - r2_keras: 0.9781 - val_loss: 0.2665 - val_r2_keras: 0.5770
# Epoch 479/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0149 - r2_keras: 0.9760 - val_loss: 0.2737 - val_r2_keras: 0.5674
# Epoch 480/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0141 - r2_keras: 0.9778 - val_loss: 0.2652 - val_r2_keras: 0.5783
# Epoch 481/500
# 5091/5091 [==============================] - 0s 26us/step - loss: 0.0170 - r2_keras: 0.9733 - val_loss: 0.2795 - val_r2_keras: 0.5595
# Epoch 482/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0156 - r2_keras: 0.9756 - val_loss: 0.2646 - val_r2_keras: 0.5800
# Epoch 483/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0142 - r2_keras: 0.9768 - val_loss: 0.2746 - val_r2_keras: 0.5663
# Epoch 484/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0147 - r2_keras: 0.9759 - val_loss: 0.2628 - val_r2_keras: 0.5823
# Epoch 485/500
# 5091/5091 [==============================] - 0s 32us/step - loss: 0.0169 - r2_keras: 0.9731 - val_loss: 0.2780 - val_r2_keras: 0.5610
# Epoch 486/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0179 - r2_keras: 0.9725 - val_loss: 0.2671 - val_r2_keras: 0.5779
# Epoch 487/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0164 - r2_keras: 0.9742 - val_loss: 0.2719 - val_r2_keras: 0.5696
# Epoch 488/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0147 - r2_keras: 0.9766 - val_loss: 0.2611 - val_r2_keras: 0.5852
# Epoch 489/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0130 - r2_keras: 0.9794 - val_loss: 0.2724 - val_r2_keras: 0.5697
# Epoch 490/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0128 - r2_keras: 0.9792 - val_loss: 0.2654 - val_r2_keras: 0.5801
# Epoch 491/500
# 5091/5091 [==============================] - 0s 24us/step - loss: 0.0120 - r2_keras: 0.9815 - val_loss: 0.2677 - val_r2_keras: 0.5761
# Epoch 492/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0122 - r2_keras: 0.9814 - val_loss: 0.2694 - val_r2_keras: 0.5732
# Epoch 493/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0139 - r2_keras: 0.9773 - val_loss: 0.2752 - val_r2_keras: 0.5653
# Epoch 494/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0128 - r2_keras: 0.9799 - val_loss: 0.2682 - val_r2_keras: 0.5758
# Epoch 495/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0136 - r2_keras: 0.9795 - val_loss: 0.2684 - val_r2_keras: 0.5753
# Epoch 496/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0152 - r2_keras: 0.9752 - val_loss: 0.2727 - val_r2_keras: 0.5689
# Epoch 497/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0141 - r2_keras: 0.9772 - val_loss: 0.2684 - val_r2_keras: 0.5760
# Epoch 498/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0143 - r2_keras: 0.9763 - val_loss: 0.2681 - val_r2_keras: 0.5756
# Epoch 499/500
# 5091/5091 [==============================] - 0s 22us/step - loss: 0.0137 - r2_keras: 0.9784 - val_loss: 0.2726 - val_r2_keras: 0.5697
# Epoch 500/500
# 5091/5091 [==============================] - 0s 23us/step - loss: 0.0128 - r2_keras: 0.9798 - val_loss: 0.2692 - val_r2_keras: 0.5733
# Time taken to run: 1.1 minutes

# %%
#evaluate model
loss_train = model_history.history['loss']
loss_val = model_history.history['val_loss']
plt.figure(figsize=(8,6))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Training and Test loss at each epoch')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score_train = model.evaluate(X_train, y_train, verbose = 0)
score_test = model.evaluate(X_test, y_test, verbose = 0)

train_r2 = round(score_train[1],4)
test_r2 = round(score_test[1],4)
train_mse = round(score_train[0],4)
test_mse = round(score_test[0],4)

metrics_df = appendToMetricsdf(metrics_df, "Neural Network", train_r2, test_r2, train_mse, test_mse)

# %% [markdown]
# ## Evaluate the Results

# %%
metrics_df
# Out:
#            Model Name  r-squared train  r-squared train test  MSE train  \
# 0  AdaBoost regressor           0.4900                0.4391     0.3214
# 1   Gradient Boosting           0.8149                0.7022     0.1167
# 2   Gradient Boosting           0.7093                0.6544     0.1832
# 3      Neural Network           0.9718                0.5083     0.0149
#
#    MSE test
# 0    0.3562
# 1    0.1891
# 2    0.2195
# 3    0.2692

# %% [markdown]
# The AdaBoost regressor showed bad r2 score. This model does not fit.
# Gradient Boosting and Extreme Gradient Boosting showed similar results. And they both can be used as basic ones.
# Finally, I trained a neural network that performs slightly worse than Gradient Boosting.

# %% [markdown]
# ## Thank you!
